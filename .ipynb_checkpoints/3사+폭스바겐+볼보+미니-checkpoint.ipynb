# %% [markdown]
# ## 볼보 ##

# %%
import os
import pandas as pd

# %% [markdown]
# ### 파일 불러오기 ###

# %%
df0 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/24.csv', encoding='utf-8')
df0
# 2017
# Out:
#     Unnamed: 0           car_name      sub_name  quentity
# 0            0                S90        2.0 D4       597
# 1            1                S90        2.0 T5       493
# 2            2                S90    2.0 D5 AWD       452
# 3            3                S90    2.0 D5 AWD       452
# 4            4                S60        2.0 D3       785
# 5            5                S60        2.0 D4       361
# 6            6                S60        2.0 T5       154
# 7            7                S60  2.0 Polestar        17
# 8            8                S60        2.0 D5         1
# 9            9                S60        2.0 D5         1
# 10          10               XC90    2.0 D5 AWD       755
# 11          11               XC90    2.0 T6 AWD       383
# 12          12               XC90    2.0 T8 AWD        81
# 13          13               XC90    2.0 T8 AWD        81
# 14          14               XC60        2.0 D4       533
# ...

# %%
df1 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/25.csv', encoding='utf-8')
df1
# 2018
# Out:
#     Unnamed: 0           car_name      sub_name quentity
# 0            0               XC60    2.0 D5 AWD    2,069
# 1            1               XC60    2.0 T6 AWD      716
# 2            2               XC60    2.0 D4 AWD      177
# 3            3               XC60    2.0 T8 AWD       30
# 4            4               XC60    2.0 T8 AWD       30
# 5            5               XC90    2.0 D5 AWD    1,095
# 6            6               XC90    2.0 T6 AWD      531
# 7            7               XC90    2.0 T8 AWD      103
# 8            8               XC90    2.0 T8 AWD      103
# 9            9                S90        2.0 T5      677
# 10          10                S90        2.0 D4      470
# 11          11                S90    2.0 D5 AWD       49
# 12          12                S90    2.0 D5 AWD       49
# 13          13                S60        2.0 D3      746
# 14          14                S60        2.0 D4      258
# ...

# %%
df2 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/26.csv', encoding='utf-8')
df2
# 2019
# Out:
#     Unnamed: 0           car_name    sub_name quentity
# 0            0               XC60  2.0 D5 AWD    2,179
# 1            1               XC60  2.0 T6 AWD      911
# 2            2               XC60  2.0 T8 AWD      116
# 3            3               XC60  2.0 T8 AWD      116
# 4            4               XC40  2.0 T4 AWD    1,760
# 5            5               XC40  2.0 T4 AWD    1,760
# 6            6                S90      2.0 T5    1,323
# 7            7                S90  2.0 D5 AWD      355
# 8            8                S90  2.0 T8 AWD       25
# 9            9                S90  2.0 T8 AWD       25
# 10          10                S60      2.0 T5    1,276
# 11          11                S60      2.0 T5    1,276
# 12          12               XC90  2.0 D5 AWD      754
# 13          13               XC90  2.0 T6 AWD      334
# 14          14               XC90  2.0 T8 AWD       80
# 15          15               XC90  2.0 T8 AWD       80
# ...

# %%
df3 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/27.csv', encoding='utf-8')
df3
# 2020
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
df4 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/28.csv', encoding='utf-8')
df4
# 2021
# Out:
#     Unnamed: 0           car_name    sub_name quentity
# 0            0               XC60  2.0 T8 AWD      983
# 1            1               XC60      B5 AWD      285
# 2            2               XC60      B6 AWD      133
# 3            3               XC60      B6 AWD      133
# 4            4               XC40      B4 AWD    1,210
# 5            5               XC40      B4 AWD    1,210
# 6            6                S90          B5      945
# 7            7                S90      B6 AWD      142
# 8            8                S90      B6 AWD      142
# 9            9                S60          B5      875
# 10          10                S60          B5      875
# 11          11  V60 Cross Country      B5 AWD      721
# 12          12  V60 Cross Country      B5 AWD      721
# 13          13               XC90  2.0 T8 AWD      464
# 14          14               XC90      B6 AWD      155
# 15          15               XC90      B6 AWD      155
# ...

# %%
# 컬럼명변경
df0 = df0.rename({'Unnamed: 0': 'year'}, axis=1)
df1 = df1.rename({'Unnamed: 0': 'year'}, axis=1)
df2 = df2.rename({'Unnamed: 0': 'year'}, axis=1)
df3 = df3.rename({'Unnamed: 0': 'year'}, axis=1)
df4 = df4.rename({'Unnamed: 0': 'year'}, axis=1)

# %%
df0["year"]=2017
df1["year"]=2018
df2["year"]=2019
df3["year"]=2020
df4["year"]=2021

# %%
df0
# Out:
#     year           car_name      sub_name  quentity
# 0   2017                S90        2.0 D4       597
# 1   2017                S90        2.0 T5       493
# 2   2017                S90    2.0 D5 AWD       452
# 3   2017                S90    2.0 D5 AWD       452
# 4   2017                S60        2.0 D3       785
# 5   2017                S60        2.0 D4       361
# 6   2017                S60        2.0 T5       154
# 7   2017                S60  2.0 Polestar        17
# 8   2017                S60        2.0 D5         1
# 9   2017                S60        2.0 D5         1
# 10  2017               XC90    2.0 D5 AWD       755
# 11  2017               XC90    2.0 T6 AWD       383
# 12  2017               XC90    2.0 T8 AWD        81
# 13  2017               XC90    2.0 T8 AWD        81
# 14  2017               XC60        2.0 D4       533
# 15  2017               XC60        2.0 D3       513
# 16  2017               XC60        2.4 D5       138
# ...

# %%
df1
# Out:
#     year           car_name      sub_name quentity
# 0   2018               XC60    2.0 D5 AWD    2,069
# 1   2018               XC60    2.0 T6 AWD      716
# 2   2018               XC60    2.0 D4 AWD      177
# 3   2018               XC60    2.0 T8 AWD       30
# 4   2018               XC60    2.0 T8 AWD       30
# 5   2018               XC90    2.0 D5 AWD    1,095
# 6   2018               XC90    2.0 T6 AWD      531
# 7   2018               XC90    2.0 T8 AWD      103
# 8   2018               XC90    2.0 T8 AWD      103
# 9   2018                S90        2.0 T5      677
# 10  2018                S90        2.0 D4      470
# 11  2018                S90    2.0 D5 AWD       49
# 12  2018                S90    2.0 D5 AWD       49
# 13  2018                S60        2.0 D3      746
# 14  2018                S60        2.0 D4      258
# 15  2018                S60        2.0 T5      162
# 16  2018                S60  2.0 Polestar       12
# ...

# %%
df2
# Out:
#     year           car_name    sub_name quentity
# 0   2019               XC60  2.0 D5 AWD    2,179
# 1   2019               XC60  2.0 T6 AWD      911
# 2   2019               XC60  2.0 T8 AWD      116
# 3   2019               XC60  2.0 T8 AWD      116
# 4   2019               XC40  2.0 T4 AWD    1,760
# 5   2019               XC40  2.0 T4 AWD    1,760
# 6   2019                S90      2.0 T5    1,323
# 7   2019                S90  2.0 D5 AWD      355
# 8   2019                S90  2.0 T8 AWD       25
# 9   2019                S90  2.0 T8 AWD       25
# 10  2019                S60      2.0 T5    1,276
# 11  2019                S60      2.0 T5    1,276
# 12  2019               XC90  2.0 D5 AWD      754
# 13  2019               XC90  2.0 T6 AWD      334
# 14  2019               XC90  2.0 T8 AWD       80
# 15  2019               XC90  2.0 T8 AWD       80
# 16  2019  V60 Cross Country  2.0 T5 AWD    1,108
# 17  2019  V60 Cross Country  2.0 T5 AWD    1,108
# ...

# %%
df3
# Out:
# Empty DataFrame
# Columns: [year]
# Index: []

# %%
df4
# Out:
#     year           car_name    sub_name quentity
# 0   2021               XC60  2.0 T8 AWD      983
# 1   2021               XC60      B5 AWD      285
# 2   2021               XC60      B6 AWD      133
# 3   2021               XC60      B6 AWD      133
# 4   2021               XC40      B4 AWD    1,210
# 5   2021               XC40      B4 AWD    1,210
# 6   2021                S90          B5      945
# 7   2021                S90      B6 AWD      142
# 8   2021                S90      B6 AWD      142
# 9   2021                S60          B5      875
# 10  2021                S60          B5      875
# 11  2021  V60 Cross Country      B5 AWD      721
# 12  2021  V60 Cross Country      B5 AWD      721
# 13  2021               XC90  2.0 T8 AWD      464
# 14  2021               XC90      B6 AWD      155
# 15  2021               XC90      B6 AWD      155
# 16  2021  V90 Cross Country      B5 AWD      205
# 17  2021  V90 Cross Country      B6 AWD        7
# ...

# %%
# 합치기
result = pd.concat([df0, df1, df2, df3, df4])
result
# Out:
#     year           car_name    sub_name quentity
# 0   2017                S90      2.0 D4      597
# 1   2017                S90      2.0 T5      493
# 2   2017                S90  2.0 D5 AWD      452
# 3   2017                S90  2.0 D5 AWD      452
# 4   2017                S60      2.0 D3      785
# ..   ...                ...         ...      ...
# 16  2021  V90 Cross Country      B5 AWD      205
# 17  2021  V90 Cross Country      B6 AWD        7
# 18  2021  V90 Cross Country      B6 AWD        7
# 19  2021                S90  2.0 T8 AWD       53
# 20  2021                S90  2.0 T8 AWD       53
#
# [127 rows x 4 columns]

# %%
result.to_csv("Volvo2017_2021.csv")
