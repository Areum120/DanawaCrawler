# %% [markdown]
# ## 아우디 ##

# %%
import os
import pandas as pd

# %% [markdown]
# ### 파일 불러오기 ###

# %%
df0 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/10.csv', encoding='utf-8')
df0
# 2017
# Out:
#     Unnamed: 0 car_name             sub_name  quentity
# 0            0       A7       50 TDI quattro       627
# 1            1       A7               40 TDI        36
# 2            2       A7       55 TDI quattro        22
# 3            3       A7      50 TFSI quattro         8
# 4            4       A7      50 TFSI quattro         8
# 5            5       A6       40 TDI quattro       151
# 6            6       A6       55 TDI quattro        68
# 7            7       A6      50 TFSI quattro        58
# 8            8       A6       50 TDI quattro        58
# 9            9       A6  S6 4.0 TFSI quattro         2
# 10          10       A6  S6 4.0 TFSI quattro         2
# 11          11       A4              45 TFSI        63
# 12          12       A4      45 TFSI quattro        11
# 13          13       A4       55 TDI quattro         1
# 14          14       A4       55 TDI quattro         1
# 15          15       R8   5.2 FSI Plus Coupe        43
# ...

# %%
df1 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/11.csv', encoding='utf-8')
df1
# 2018
# Out:
#     Unnamed: 0 car_name            sub_name quentity
# 0            0       A6              35 TDI    5,194
# 1            1       A6      35 TDI quattro    1,551
# 2            2       A6             40 TFSI    1,255
# 3            3       A6     40 TFSI quattro      153
# 4            4       A6     40 TFSI quattro      153
# 5            5       A3             40 TFSI    3,048
# 6            6       A3             40 TFSI    3,048
# 7            7       A4              30 TDI      789
# 8            8       A4              35 TDI      481
# 9            9       A4      35 TDI quattro      409
# 10          10       A4      35 TDI quattro      409
# 11          11       A7      50 TDI quattro      214
# 12          12       A7      50 TDI quattro      214
# 13          13       R8  5.2 FSI Plus Coupe       56
# 14          14       R8  5.2 FSI Plus Coupe       56

# %%
df2 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/12.csv', encoding='utf-8')
df2
# 2019
# Out:
#     Unnamed: 0 car_name                   sub_name quentity
# 0            0       Q7            45 TFSI quattro    4,156
# 1            1       Q7            45 TFSI quattro    4,156
# 2            2       A6            45 TFSI quattro    2,666
# 3            3       A6                     40 TDI      354
# 4            4       A6                     40 TDI      354
# 5            5       A6                    40 TFSI    2,460
# 6            6       A6            40 TFSI quattro      100
# 7            7       A6            40 TFSI quattro      100
# 8            8       A4                    40 TFSI    1,230
# 9            9       A4                    40 TFSI    1,230
# 10          10       A5  Sportback 45 TFSI quattro    1,099
# 11          11       A5  Cabriolet 45 TFSI quattro       23
# 12          12       A5      Coupe 45 TFSI quattro       16
# 13          13       A5      Coupe 45 TFSI quattro       16
# 14          14       A3                    40 TFSI      447
# ...

# %%
df3 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/13.csv', encoding='utf-8')
df3
# 2020
# Out:
#     Unnamed: 0 car_name                   sub_name quentity
# 0            0       A6                     40 TDI    4,923
# 1            1       A6                    45 TFSI    2,483
# 2            2       A6            45 TFSI quattro    2,144
# 3            3       A6             40 TDI quattro    1,102
# 4            4       A6             45 TDI quattro      840
# 5            5       A6             50 TDI quattro       80
# 6            6       A6                     S6 TDI       40
# 7            7       A6                     S6 TDI       40
# 8            8       Q3                     35 TDI    1,423
# 9            9       Q3           Sportback 35 TDI      736
# 10          10       Q3           Sportback 35 TDI      736
# 11          11       A7            55 TFSI quattro    1,206
# 12          12       A7             50 TDI quattro      700
# 13          13       A7             45 TDI quattro      148
# 14          14       A7                     S7 TDI       93
# ...

# %%
df4 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/14.csv', encoding='utf-8')
df4
# 2021
# Out:
#     Unnamed: 0         car_name                   sub_name quentity
# 0            0               A6                    45 TFSI    1,675
# 1            1               A6            45 TFSI quattro    1,553
# 2            2               A6                     40 TDI      762
# 3            3               A6             40 TDI quattro      392
# 4            4               A6             45 TDI quattro      315
# 5            5               A6             50 TDI quattro       67
# 6            6               A6                     S6 TDI       20
# 7            7               A6                     S6 TDI       20
# 8            8               A7            55 TFSI quattro      693
# 9            9               A7             50 TDI quattro      185
# 10          10               A7             45 TDI quattro      129
# 11          11               A7                     S7 TDI       44
# 12          12               A7                     S7 TDI       44
# ...

# %%
# 컬럼명변경
df0 = df0.rename({'Unnamed: 0': 'year'}, axis=1)
df1 = df1.rename({'Unnamed: 0': 'year'}, axis=1)
df2 = df2.rename({'Unnamed: 0': 'year'}, axis=1)
df3 = df3.rename({'Unnamed: 0': 'year'}, axis=1)
df4 = df4.rename({'Unnamed: 0': 'year'}, axis=1)

# %%
df0["year"]=2017
df1["year"]=2018
df2["year"]=2019
df3["year"]=2020
df4["year"]=2021

# %%
df0
# Out:
#     year car_name             sub_name  quentity
# 0   2017       A7       50 TDI quattro       627
# 1   2017       A7               40 TDI        36
# 2   2017       A7       55 TDI quattro        22
# 3   2017       A7      50 TFSI quattro         8
# 4   2017       A7      50 TFSI quattro         8
# 5   2017       A6       40 TDI quattro       151
# 6   2017       A6       55 TDI quattro        68
# 7   2017       A6      50 TFSI quattro        58
# 8   2017       A6       50 TDI quattro        58
# 9   2017       A6  S6 4.0 TFSI quattro         2
# 10  2017       A6  S6 4.0 TFSI quattro         2
# 11  2017       A4              45 TFSI        63
# 12  2017       A4      45 TFSI quattro        11
# 13  2017       A4       55 TDI quattro         1
# 14  2017       A4       55 TDI quattro         1
# 15  2017       R8   5.2 FSI Plus Coupe        43
# 16  2017       R8   5.2 FSI Plus Coupe        43
# 17  2017       Q5       45 TDI quattro        16
# ...

# %%
df1
# Out:
#     year car_name            sub_name quentity
# 0   2018       A6              35 TDI    5,194
# 1   2018       A6      35 TDI quattro    1,551
# 2   2018       A6             40 TFSI    1,255
# 3   2018       A6     40 TFSI quattro      153
# 4   2018       A6     40 TFSI quattro      153
# 5   2018       A3             40 TFSI    3,048
# 6   2018       A3             40 TFSI    3,048
# 7   2018       A4              30 TDI      789
# 8   2018       A4              35 TDI      481
# 9   2018       A4      35 TDI quattro      409
# 10  2018       A4      35 TDI quattro      409
# 11  2018       A7      50 TDI quattro      214
# 12  2018       A7      50 TDI quattro      214
# 13  2018       R8  5.2 FSI Plus Coupe       56
# 14  2018       R8  5.2 FSI Plus Coupe       56

# %%
df2
# Out:
#     year car_name                   sub_name quentity
# 0   2019       Q7            45 TFSI quattro    4,156
# 1   2019       Q7            45 TFSI quattro    4,156
# 2   2019       A6            45 TFSI quattro    2,666
# 3   2019       A6                     40 TDI      354
# 4   2019       A6                     40 TDI      354
# 5   2019       A6                    40 TFSI    2,460
# 6   2019       A6            40 TFSI quattro      100
# 7   2019       A6            40 TFSI quattro      100
# 8   2019       A4                    40 TFSI    1,230
# 9   2019       A4                    40 TFSI    1,230
# 10  2019       A5  Sportback 45 TFSI quattro    1,099
# 11  2019       A5  Cabriolet 45 TFSI quattro       23
# 12  2019       A5      Coupe 45 TFSI quattro       16
# 13  2019       A5      Coupe 45 TFSI quattro       16
# 14  2019       A3                    40 TFSI      447
# 15  2019       A3                    40 TFSI      447
# ...

# %%
df3
# Out:
#     year car_name                   sub_name quentity
# 0   2020       A6                     40 TDI    4,923
# 1   2020       A6                    45 TFSI    2,483
# 2   2020       A6            45 TFSI quattro    2,144
# 3   2020       A6             40 TDI quattro    1,102
# 4   2020       A6             45 TDI quattro      840
# 5   2020       A6             50 TDI quattro       80
# 6   2020       A6                     S6 TDI       40
# 7   2020       A6                     S6 TDI       40
# 8   2020       Q3                     35 TDI    1,423
# 9   2020       Q3           Sportback 35 TDI      736
# 10  2020       Q3           Sportback 35 TDI      736
# 11  2020       A7            55 TFSI quattro    1,206
# 12  2020       A7             50 TDI quattro      700
# 13  2020       A7             45 TDI quattro      148
# 14  2020       A7                     S7 TDI       93
# 15  2020       A7                     S7 TDI       93
# ...

# %%
df4
# Out:
#     year         car_name                   sub_name quentity
# 0   2021               A6                    45 TFSI    1,675
# 1   2021               A6            45 TFSI quattro    1,553
# 2   2021               A6                     40 TDI      762
# 3   2021               A6             40 TDI quattro      392
# 4   2021               A6             45 TDI quattro      315
# 5   2021               A6             50 TDI quattro       67
# 6   2021               A6                     S6 TDI       20
# 7   2021               A6                     S6 TDI       20
# 8   2021               A7            55 TFSI quattro      693
# 9   2021               A7             50 TDI quattro      185
# 10  2021               A7             45 TDI quattro      129
# 11  2021               A7                     S7 TDI       44
# 12  2021               A7                     S7 TDI       44
# 13  2021               Q8             50 TDI quattro      338
# ...

# %%
# 합치기
result = pd.concat([df0, df1, df2, df3, df4])
result
# Out:
#     year         car_name         sub_name quentity
# 0   2017               A7   50 TDI quattro      627
# 1   2017               A7           40 TDI       36
# 2   2017               A7   55 TDI quattro       22
# 3   2017               A7  50 TFSI quattro        8
# 4   2017               A7  50 TFSI quattro        8
# ..   ...              ...              ...      ...
# 50  2021               Q3           35 TDI       27
# 51  2021               Q2           35 TDI       38
# 52  2021               Q2           35 TDI       38
# 53  2021  The new audi R8  V10 performance       32
# 54  2021  The new audi R8  V10 performance       32
#
# [174 rows x 4 columns]

# %%
result.to_csv("Audi2017_2021.csv")
